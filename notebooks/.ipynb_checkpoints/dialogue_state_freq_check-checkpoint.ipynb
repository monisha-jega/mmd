# %%
import pickle
import os, json, pickle

train_dir = "../../../dataset/v1/train/"


state_count_map = {}
state_subtypes = {}
count = 0
for json_name in os.listdir(train_dir)[:2]:
	dialogue = json.load(open(train_dir + json_name))
	for utterance_ in dialogue:


		utterance = utterance_["utterance"]
        
		state = utterance_["type"]
        if state == "answer":
            continue
		substate = None
		if state == "question":
			if "question-type" in utterance_:
				state = utterance_["question-type"]
			if "question-subtype" in utterance_:
				substate = utterance_["question-subtype"]

		if state not in state_count_map:
			state_count_map[state] = 1
			if substate != None:
				state_subtypes[state] = set([substate])
		else:
			state_count_map[state] += 1
			if substate != None:
				state_subtypes[state].add(substate)
                
		if count % 1000000 == 1:
			print(count)
		count += 1
            

for state, scount in state_count_map.items():
    print "\n", state, scount*100/float(count)
    print state_subtypes.get(state)
# Out:
# 1
#
# show_similar_to 4.41176470588
# set([u'show_similar_to_n_in_attribute_complement_value', u'show_similar_to_n'])
#
# switch-synset 1.47058823529
# None
#
# question 10.2941176471
# None
#
# greeting 5.88235294118
# None
#
# exit-message 5.88235294118
# None
#
# repeat-question 7.35294117647
# None
#
# suited_for 5.88235294118
# set([u'ask_if_n_suited_for', u'ask_if_synset_in_n_suited_for', u'ask_what_other_synset_suited_for_style'])
#
# like_n_show_result 1.47058823529
# set([u'like_n_show_in_attribute_complement_value'])
#
# answer 47.0588235294
# None
#
# show_orientation 4.41176470588
# set([u'show_all_orientations_of_n', u'show_different_orientation_of_n'])
#
# celebrity 1.47058823529
# set([u'which_celebrity_endorses_n'])
#
# go_with 2.94117647059
# set([u'ask_if_synset_will_go_with_any', u'ask_if_synset_attribute_in_n_will_go_with_image'])
#
# do_not_like_n_show_result 1.47058823529
# set([u'do_not_like_n_show_in_attribute_as_in_m'])
